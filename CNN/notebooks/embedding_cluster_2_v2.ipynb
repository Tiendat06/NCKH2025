# %%
# !pip install numpy matplotlib seaborn scikit-learn scipy tensorflow tqdm kneed

# %% [markdown]
# # Dependencies

# %%
import os
import cv2
import random
import numpy as np
import seaborn as sns
from tqdm import tqdm
import tensorflow as tf
import matplotlib.pyplot as plt
from collections import Counter
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from scipy.spatial.distance import cdist
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import EfficientNetB1
from tensorflow.keras.applications.efficientnet import preprocess_input

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# # Loading Embedding files

# %%
root = os.path.abspath(os.path.join(os.getcwd(), "..",))
data_folder = os.path.join(root, "data")

train_dataset = os.path.join(data_folder, "train")
val_dataset = os.path.join(data_folder, "val")
test_dataset = os.path.join(data_folder, "test")

print(train_dataset)
print(val_dataset)
print(test_dataset)
# Out:
# d:\Code\NCKH2025\CNN\data\train
# d:\Code\NCKH2025\CNN\data\val
# d:\Code\NCKH2025\CNN\data\test

# %%
class_names = [d for d in os.listdir(train_dataset) if os.path.isdir(os.path.join(train_dataset, d))]
num_classes = len(class_names)
embeddings = []
images = []

# %%
total_files = sum(len([f for f in os.listdir(os.path.join(train_dataset, c)) if f.endswith('.npy')]) for c in class_names)

with tqdm(total=total_files, desc="Loading embeddings", unit="file") as pbar:
    for class_name in class_names:
        class_path = os.path.join(train_dataset, class_name)
        npy_files = [f for f in os.listdir(class_path) if f.endswith('.npy')]

        for file in npy_files:
            file_path = os.path.join(class_path, file)
            embeddings.append(np.load(file_path))
            images.append(file_path.replace('.npy', '.jpg'))
            pbar.update(1)
# Out:
# Loading embeddings: 100%|██████████| 8010/8010 [00:01<00:00, 6208.03file/s]

# %% [markdown]
# # Process Embeddings

# %%
embeddings = np.array(embeddings)
print(f"Shape embeddings: {embeddings.shape}")
# Out:
# Shape embeddings: (8010, 2)

# %% [markdown]
# # Run K-Means

# %%
k_values = range(1, num_classes + 1)
wcss = []

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(embeddings)
    wcss.append(kmeans.inertia_)  # inertia_ là tổng WCSS

# Vẽ biểu đồ Elbow
plt.figure(figsize=(8, 5))
plt.plot(k_values, wcss, marker='o', linestyle='--')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('WCSS')
plt.title('Elbow Method to Find Optimal k')
plt.show()

# %%
from kneed import KneeLocator

knee = KneeLocator(k_values, wcss, curve='convex', direction='decreasing')
optimal_k = knee.knee

print(f"Optimal k: {optimal_k}")
# Out:
# Optimal k: 3

# %%
# Chạy K-Means trên dữ liệu đã giảm chiều
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
kmeans.fit(embeddings)

# Lấy nhãn cụm và centroid
cluster_labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# %% [markdown]
# # Plot

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=embeddings[:, 0], y=embeddings[:, 1], hue=cluster_labels, palette="bright", alpha=0.8)

plt.scatter(centroids[:, 0], centroids[:, 1], marker="X", s=100, c="red", edgecolors="black", label="Centroids")

plt.title("K-Means Clustering with Centroids")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.legend(title="Cluster")
plt.show()

# %% [markdown]
# # Data Distributtion

# %%
# Đếm số lượng mẫu trong mỗi cụm
cluster_counts = Counter(cluster_labels)

# Hiển thị số lượng mẫu theo từng cụm
print("Phân bố dữ liệu theo cụm:")
for cluster, count in sorted(cluster_counts.items()):
    print(f"Cụm {cluster}: {count} mẫu")
# Out:
# Phân bố dữ liệu theo cụm:
# Cụm 0: 2756 mẫu
# Cụm 1: 3203 mẫu
# Cụm 2: 2051 mẫu

# %%
plt.figure(figsize=(8, 5))
ax = sns.barplot(x=list(cluster_counts.keys()), 
                 y=list(cluster_counts.values()), 
                 hue=list(cluster_counts.keys()),
                 palette="bright", 
                 legend=False)  

for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', 
                fontsize=12, fontweight="bold", color="black")
    
plt.xlabel("Cụm")
plt.ylabel("Số lượng mẫu")
plt.title("Phân bố dữ liệu theo từng cụm")
plt.show()

# %% [markdown]
# # Evaluate

# %%
# Tính khoảng cách từ mỗi điểm đến centroid tương ứng
distances = np.min(cdist(embeddings, centroids, "euclidean"), axis=1)

# Trung bình khoảng cách tới tâm cụm
avg_distance = np.mean(distances)

print(f"Khoảng cách trung bình tới tâm cụm: {avg_distance:.2f}")
# Out:
# Khoảng cách trung bình tới tâm cụm: 0.26

# %%
# Vẽ histogram phân bố khoảng cách
plt.figure(figsize=(10, 5))
sns.histplot(distances, bins=50, kde=True, color="blue")
plt.xlabel("Khoảng cách tới tâm cụm")
plt.ylabel("Số lượng mẫu")
plt.title("Phân bố khoảng cách tới tâm cụm")
plt.show()

# %% [markdown]
# # Saliency map

# %%
pretrained_model = EfficientNetB1(
    include_top=True,
    weights='imagenet',
    pooling='avg'
)
pretrained_model.trainable = False

# %%
def compute_saliency_map(img_path):
    """Tính Saliency Map cho một ảnh sử dụng EfficientNetB1."""
    img = image.load_img(img_path, target_size=(240, 240))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    img_tensor = tf.convert_to_tensor(img_array)

    with tf.GradientTape() as tape:
        tape.watch(img_tensor)
        preds = pretrained_model(img_tensor)  # Dự đoán toàn bộ lớp
        class_idx = tf.argmax(preds[0])  # Xác định class có xác suất cao nhất
        loss = preds[:, class_idx]  # Lấy xác suất của class cao nhất

    gradients = tape.gradient(loss, img_tensor)[0]  # Gradient của ảnh đầu vào
    saliency_map = np.max(np.abs(gradients), axis=-1)  # Lấy max theo kênh màu

    # Chuẩn hóa về [0,1]
    saliency_map -= saliency_map.min()
    saliency_map /= saliency_map.max()
    return saliency_map, img

# %%
num_clusters = len(cluster_counts)  
fig, axes = plt.subplots(2, num_clusters, figsize=(20, 10))

for cluster_id in tqdm(range(num_clusters), desc="Processing Clusters"):
    cluster_indices = np.where(cluster_labels == cluster_id)[0]

    if len(cluster_indices) == 0:
        continue

    random_indices = random.sample(list(cluster_indices), 100)

    saliency_maps = []
    original_images = []

    for idx in tqdm(random_indices, desc=f"Cluster {cluster_id}", leave=False):
        saliency_map, img = compute_saliency_map(images[idx])
        saliency_maps.append(saliency_map)
        original_images.append(img)

    # Tính trung bình Saliency Map của cụm
    mean_saliency_map = np.mean(np.array(saliency_maps), axis=0)

    # Hiển thị ảnh gốc ngẫu nhiên đầu tiên của cụm
    axes[0, cluster_id].set_title(f"Cluster {cluster_id}")
    axes[0, cluster_id].imshow(original_images[0])
    axes[0, cluster_id].axis("off")

    # Hiển thị Saliency Map trung bình
    axes[1, cluster_id].imshow(mean_saliency_map, cmap="jet")
    axes[1, cluster_id].axis("off")

plt.tight_layout()  # Tự động căn chỉnh bố cục tốt hơn
plt.show()
# Out:
# Processing Clusters: 100%|██████████| 3/3 [01:55<00:00, 38.51s/it]
